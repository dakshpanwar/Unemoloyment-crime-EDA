# %% [markdown]
# # Project: Unemployment and Crime Analysis

# %% [markdown]
# ###

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime as dtime

# %%
os.chdir("C:/Users/Daksh/Desktop/python")
os.getcwd()
# Out:
# 'C:\\Users\\Daksh\\Desktop\\python'

# %% [markdown]
# ## DATA WRANGLING

# %% [markdown]
# **In this step we will Clean our data and make it ready to analyse**

# %% [markdown]
# #### CLEANING THE UNEMPLOYMENT RATE DATASET

# %%
df1 = pd.read_csv('unemployment.csv')
df2 = pd.read_csv('crime.csv')

# %%
df1.head()
# Out:
#          Data Source World Development Indicators  \
# 0                NaN                          NaN
# 1  Last Updated Date                    5/25/2022
# 2                NaN                          NaN
# 3       Country Name                 Country Code
# 4              Aruba                          ABW
#
#                                           Unnamed: 2      Unnamed: 3  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3                                     Indicator Name  Indicator Code
# 4  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
#
#    Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
df1.shape
# Out:
# (270, 66)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 66 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Data Source                   268 non-null    object
#  1   World Development Indicators  268 non-null    object
#  2   Unnamed: 2                    267 non-null    object
#  3   Unnamed: 3                    267 non-null    object
#  4   Unnamed: 4                    1 non-null      float64
#  5   Unnamed: 5                    1 non-null      float64
#  6   Unnamed: 6                    1 non-null      float64
#  7   Unnamed: 7                    1 non-null      float64
#  8   Unnamed: 8                    1 non-null      float64
#  9   Unnamed: 9                    1 non-null      float64
#  10  Unnamed: 10                   1 non-null      float64
#  11  Unnamed: 11                   1 non-null      float64
# ...

# %%
df1 = df1.drop(labels=[0,1,2], axis=0)

# %%
df1.head()
# Out:
#                    Data Source World Development Indicators  \
# 3                 Country Name                 Country Code
# 4                        Aruba                          ABW
# 5  Africa Eastern and Southern                          AFE
# 6                  Afghanistan                          AFG
# 7   Africa Western and Central                          AFW
#
#                                           Unnamed: 2      Unnamed: 3  \
# 3                                     Indicator Name  Indicator Code
# 4  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# 5  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# 6  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# 7  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
#
#    Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 3      1960.0      1961.0      1962.0      1963.0      1964.0      1965.0
# ...

# %%
df1.columns = df1.iloc[0]
df1 = df1[1:]

# %%
df1
# Out:
# 3                   Country Name Country Code  \
# 4                          Aruba          ABW
# 5    Africa Eastern and Southern          AFE
# 6                    Afghanistan          AFG
# 7     Africa Western and Central          AFW
# 8                         Angola          AGO
# ..                           ...          ...
# 265                       Kosovo          XKX
# 266                  Yemen, Rep.          YEM
# 267                 South Africa          ZAF
# 268                       Zambia          ZMB
# 269                     Zimbabwe          ZWE
#
# 3                                       Indicator Name  Indicator Code  \
# 4    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# 5    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# 6    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# 7    Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS
# ...

# %%
df1.drop('Country Code', inplace=True,axis = 1)
df1.drop('Indicator Name', inplace=True,axis = 1)
df1.drop('Indicator Code', inplace=True,axis = 1)

# %%
df1.head()
# Out:
# 3                 Country Name  1960.0  1961.0  1962.0  1963.0  1964.0  \
# 4                        Aruba     NaN     NaN     NaN     NaN     NaN
# 5  Africa Eastern and Southern     NaN     NaN     NaN     NaN     NaN
# 6                  Afghanistan     NaN     NaN     NaN     NaN     NaN
# 7   Africa Western and Central     NaN     NaN     NaN     NaN     NaN
# 8                       Angola     NaN     NaN     NaN     NaN     NaN
#
# 3  1965.0  1966.0  1967.0  1968.0  ...     2012.0     2013.0     2014.0  \
# 4     NaN     NaN     NaN     NaN  ...        NaN        NaN        NaN
# 5     NaN     NaN     NaN     NaN  ...   6.562179   6.445456   6.405196
# 6     NaN     NaN     NaN     NaN  ...  11.341000  11.193000  11.142000
# 7     NaN     NaN     NaN     NaN  ...   4.637602   4.410216   4.688088
# 8     NaN     NaN     NaN     NaN  ...   7.347000   7.366000   7.372000
#
# 3     2015.0     2016.0     2017.0     2018.0     2019.0     2020.0     2021.0
# ...

# %%
df1 = df1.fillna(0)

# %%
df1.drop(df1.iloc[:, 1:53], inplace = True, axis = 1)

# %%
df1.head()
# Out:
# 3                 Country Name     2012.0     2013.0     2014.0     2015.0  \
# 4                        Aruba   0.000000   0.000000   0.000000   0.000000
# 5  Africa Eastern and Southern   6.562179   6.445456   6.405196   6.490041
# 6                  Afghanistan  11.341000  11.193000  11.142000  11.127000
# 7   Africa Western and Central   4.637602   4.410216   4.688088   4.626737
# 8                       Angola   7.347000   7.366000   7.372000   7.392000
#
# 3     2016.0     2017.0     2018.0     2019.0     2020.0     2021.0
# 4   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 5   6.610205   6.714955   6.731163   6.914353   7.563187   8.111783
# 6  11.158000  11.180000  11.152000  11.217000  11.710000  13.283000
# 7   5.567017   6.019505   6.041092   6.063362   6.774914   6.839009
# 8   7.412000   7.408000   7.421000   7.421000   8.333000   8.530000

# %%
unem = df1[df1["Country Name"].isin(["India", "China", "Japan","Russian Federation","United States","Germany","United Kingdom","France"])]

# %%
unem
# Out:
# 3          Country Name  2012.0  2013.0  2014.0  2015.0  2016.0  2017.0  \
# 44                China   4.570   4.590   4.610   4.630   4.530   4.440
# 59              Germany   5.380   5.230   4.980   4.620   4.120   3.750
# 81               France   9.400   9.920  10.290  10.350  10.050   9.410
# 85       United Kingdom   7.880   7.520   6.110   5.300   4.810   4.330
# 113               India   5.414   5.424   5.436   5.435   5.423   5.358
# 123               Japan   4.360   4.000   3.600   3.400   3.100   2.800
# 206  Russian Federation   5.440   5.460   5.160   5.570   5.560   5.210
# 255       United States   8.070   7.370   6.170   5.280   4.870   4.360
#
# 3    2018.0  2019.0  2020.0  2021.0
# 44     4.28    4.52   5.000   4.817
# 59     3.38    3.14   3.810   3.535
# 81     9.02    8.41   8.010   8.063
# 85     4.00    3.74   4.472   4.526
# 113    5.33    5.27   7.997   5.978
# 123    2.40    2.40   2.800   2.799
# 206    4.85    4.50   5.590   5.010
# ...

# %%
unem.columns.values
# Out:
# array(['Country Name', 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0,
#        2018.0, 2019.0, 2020.0, 2021.0], dtype=object)

# %%
unem.columns.name = None

# %%
unem = unem.set_index('Country Name')
unem
# Out:
#                     2012.0  2013.0  2014.0  2015.0  2016.0  2017.0  2018.0  \
# Country Name
# China                4.570   4.590   4.610   4.630   4.530   4.440    4.28
# Germany              5.380   5.230   4.980   4.620   4.120   3.750    3.38
# France               9.400   9.920  10.290  10.350  10.050   9.410    9.02
# United Kingdom       7.880   7.520   6.110   5.300   4.810   4.330    4.00
# India                5.414   5.424   5.436   5.435   5.423   5.358    5.33
# Japan                4.360   4.000   3.600   3.400   3.100   2.800    2.40
# Russian Federation   5.440   5.460   5.160   5.570   5.560   5.210    4.85
# United States        8.070   7.370   6.170   5.280   4.870   4.360    3.90
#
#                     2019.0  2020.0  2021.0
# Country Name
# China                 4.52   5.000   4.817
# Germany               3.14   3.810   3.535
# France                8.41   8.010   8.063
# United Kingdom        3.74   4.472   4.526
# India                 5.27   7.997   5.978
# ...

# %%
unem.describe()
# Out:
#          2012.0    2013.0     2014.0     2015.0     2016.0    2017.0  \
# count  8.000000  8.000000   8.000000   8.000000   8.000000  8.000000
# mean   6.314250  6.189250   5.794500   5.573125   5.307875  4.957250
# std    1.865674  1.944647   1.995117   2.053518   2.066572  1.970509
# min    4.360000  4.000000   3.600000   3.400000   3.100000  2.800000
# 25%    5.177500  5.070000   4.887500   4.627500   4.427500  4.185000
# 50%    5.427000  5.442000   5.298000   5.290000   4.840000  4.400000
# 75%    7.927500  7.407500   6.125000   5.468750   5.457250  5.247000
# max    9.400000  9.920000  10.290000  10.350000  10.050000  9.410000
#
#          2018.0    2019.0    2020.0    2021.0
# count  8.000000  8.000000  8.000000  8.000000
# mean   4.645000  4.456250  5.716125  5.024000
# std    1.978326  1.828043  2.074502  1.594546
# min    2.400000  2.400000  2.800000  2.799000
# 25%    3.770000  3.537500  4.306500  4.278250
# 50%    4.140000  4.120000  5.295000  4.913500
# ...

# %%
# also transpose of unemployment rate dataset
unemt = unem.transpose()
unemt
# Out:
# Country Name  China  Germany  France  United Kingdom  India  Japan  \
# 2012.0        4.570    5.380   9.400           7.880  5.414  4.360
# 2013.0        4.590    5.230   9.920           7.520  5.424  4.000
# 2014.0        4.610    4.980  10.290           6.110  5.436  3.600
# 2015.0        4.630    4.620  10.350           5.300  5.435  3.400
# 2016.0        4.530    4.120  10.050           4.810  5.423  3.100
# 2017.0        4.440    3.750   9.410           4.330  5.358  2.800
# 2018.0        4.280    3.380   9.020           4.000  5.330  2.400
# 2019.0        4.520    3.140   8.410           3.740  5.270  2.400
# 2020.0        5.000    3.810   8.010           4.472  7.997  2.800
# 2021.0        4.817    3.535   8.063           4.526  5.978  2.799
#
# Country Name  Russian Federation  United States
# 2012.0                      5.44          8.070
# 2013.0                      5.46          7.370
# 2014.0                      5.16          6.170
# ...

# %% [markdown]
# #### CLEANING THE CRIME RATE DATASET

# %%
df2.head()
# Out:
#          Data Source World Development Indicators  \
# 0                NaN                          NaN
# 1  Last Updated Date                    5/25/2022
# 2                NaN                          NaN
# 3       Country Name                 Country Code
# 4              Aruba                          ABW
#
#                                    Unnamed: 2      Unnamed: 3  Unnamed: 4  \
# 0                                         NaN             NaN         NaN
# 1                                         NaN             NaN         NaN
# 2                                         NaN             NaN         NaN
# 3                              Indicator Name  Indicator Code      1960.0
# 4  Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# 1         NaN         NaN         NaN         NaN         NaN  ...
# ...

# %%
df3 = df2.drop(labels=[0,1,2], axis=0)

# %%
df3.head()
# Out:
#                    Data Source World Development Indicators  \
# 3                 Country Name                 Country Code
# 4                        Aruba                          ABW
# 5  Africa Eastern and Southern                          AFE
# 6                  Afghanistan                          AFG
# 7   Africa Western and Central                          AFW
#
#                                    Unnamed: 2      Unnamed: 3  Unnamed: 4  \
# 3                              Indicator Name  Indicator Code      1960.0
# 4  Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5         NaN
# 5  Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5         NaN
# 6  Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5         NaN
# 7  Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 3      1961.0      1962.0      1963.0      1964.0      1965.0  ...
# ...

# %%
df3.columns = df3.iloc[0]
df3 = df3[1:]

# %%
df4 = df3
df3.head()
# Out:
# 3                 Country Name Country Code  \
# 4                        Aruba          ABW
# 5  Africa Eastern and Southern          AFE
# 6                  Afghanistan          AFG
# 7   Africa Western and Central          AFW
# 8                       Angola          AGO
#
# 3                              Indicator Name  Indicator Code  1960.0  1961.0  \
# 4  Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5     NaN     NaN
# 5  Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5     NaN     NaN
# 6  Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5     NaN     NaN
# 7  Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5     NaN     NaN
# 8  Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5     NaN     NaN
#
# 3  1962.0  1963.0  1964.0  1965.0  ...     2012.0    2013.0     2014.0  \
# 4     NaN     NaN     NaN     NaN  ...   3.899966  5.815926   1.927228
# 5     NaN     NaN     NaN     NaN  ...  15.100000       NaN  10.500000
# ...

# %%
crm = df3[df3["Country Name"].isin(["India", "China", "Japan","Russian Federation","United States","Germany","United Kingdom","France"])]
crm
# Out:
# 3          Country Name Country Code  \
# 44                China          CHN
# 59              Germany          DEU
# 81               France          FRA
# 85       United Kingdom          GBR
# 113               India          IND
# 123               Japan          JPN
# 206  Russian Federation          RUS
# 255       United States          USA
#
# 3                                Indicator Name  Indicator Code  1960.0  \
# 44   Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5     NaN
# 59   Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5     NaN
# 81   Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5     NaN
# 85   Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5     NaN
# 113  Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5     NaN
# 123  Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5     NaN
# 206  Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5     NaN
# ...

# %%
crm.columns.values
# Out:
# array(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        1960.0, 1961.0, 1962.0, 1963.0, 1964.0, 1965.0, 1966.0, 1967.0,
#        1968.0, 1969.0, 1970.0, 1971.0, 1972.0, 1973.0, 1974.0, 1975.0,
#        1976.0, 1977.0, 1978.0, 1979.0, 1980.0, 1981.0, 1982.0, 1983.0,
#        1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0,
#        1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0,
#        2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0,
#        2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0,
#        2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0], dtype=object)

# %%
crm.drop(crm.iloc[:, 1:56], inplace = True, axis = 1)
crm
# Out:
# C:\Users\Daksh\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# 3          Country Name     2012.0     2013.0     2014.0     2015.0  \
# 44                China   0.815341   0.764432   0.720495   0.653944
# 59              Germany   0.813855   0.840167   0.879063   0.833869
# 81               France   1.233398   1.216086   1.233769   1.570132
# 85       United Kingdom   0.971712   0.927921   0.900294   0.989977
# 113               India   3.750888   3.581862   3.655138   3.386858
# 123               Japan   0.334051   0.288355   0.308188   0.283627
# 206  Russian Federation  11.283118  11.108920  11.416734  11.481183
# 255       United States   4.730549   4.525593   4.444676   4.949852
#
# ...

# %%
crm.columns.name = None
crm = crm.set_index('Country Name')
crm
# Out:
#                        2012.0     2013.0     2014.0     2015.0     2016.0  \
# Country Name
# China                0.815341   0.764432   0.720495   0.653944   0.610587
# Germany              0.813855   0.840167   0.879063   0.833869   1.171622
# France               1.233398   1.216086   1.233769   1.570132   1.351527
# United Kingdom       0.971712   0.927921   0.900294   0.989977   1.193099
# India                3.750888   3.581862   3.655138   3.386858   3.222155
# Japan                0.334051   0.288355   0.308188   0.283627   0.283337
# Russian Federation  11.283118  11.108920  11.416734  11.481183  10.919951
# United States        4.730549   4.525593   4.444676   4.949852   5.390755
#
#                       2017.0    2018.0  2019.0  2020.0  2021.0
# Country Name
# China               0.562271  0.527091     NaN     NaN     NaN
# Germany             0.983566  0.947977     NaN     NaN     NaN
# France              1.270771  1.198637     NaN     NaN     NaN
# ...

# %%
crm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, China to United States
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2012.0  8 non-null      float64
#  1   2013.0  8 non-null      float64
#  2   2014.0  8 non-null      float64
#  3   2015.0  8 non-null      float64
#  4   2016.0  8 non-null      float64
#  5   2017.0  8 non-null      float64
#  6   2018.0  8 non-null      float64
#  7   2019.0  0 non-null      float64
#  8   2020.0  0 non-null      float64
#  9   2021.0  0 non-null      float64
# dtypes: float64(10)
# memory usage: 704.0+ bytes

# %%
crm = crm.fillna(0)

# %%
crm.shape
# Out:
# (8, 10)

# %%
crm.describe()
# Out:
#           2012.0     2013.0     2014.0     2015.0     2016.0    2017.0  \
# count   8.000000   8.000000   8.000000   8.000000   8.000000  8.000000
# mean    2.991614   2.906667   2.944795   3.018680   3.017879  2.729480
# std     3.704480   3.641868   3.737876   3.770918   3.603629  3.076873
# min     0.334051   0.288355   0.308188   0.283627   0.283337  0.239995
# 25%     0.814969   0.821233   0.839421   0.788888   1.031363  0.878242
# 50%     1.102555   1.072003   1.067032   1.280054   1.272313  1.237087
# 75%     3.995803   3.817795   3.852523   3.777606   3.764305  3.672849
# max    11.283118  11.108920  11.416734  11.481183  10.919951  9.134193
#
#          2018.0  2019.0  2020.0  2021.0
# count  8.000000     8.0     8.0     8.0
# mean   2.548356     0.0     0.0     0.0
# std    2.767917     0.0     0.0     0.0
# min    0.262574     0.0     0.0     0.0
# 25%    0.842755     0.0     0.0     0.0
# 50%    1.201776     0.0     0.0     0.0
# 75%    3.548662     0.0     0.0     0.0
# ...

# %%
# Transpose of crime Data set
crmt = crm.transpose()
crmt
# Out:
# Country Name     China   Germany    France  United Kingdom     India  \
# 2012.0        0.815341  0.813855  1.233398        0.971712  3.750888
# 2013.0        0.764432  0.840167  1.216086        0.927921  3.581862
# 2014.0        0.720495  0.879063  1.233769        0.900294  3.655138
# 2015.0        0.653944  0.833869  1.570132        0.989977  3.386858
# 2016.0        0.610587  1.171622  1.351527        1.193099  3.222155
# 2017.0        0.562271  0.983566  1.270771        1.203403  3.124877
# 2018.0        0.527091  0.947977  1.198637        1.204915  3.079232
# 2019.0        0.000000  0.000000  0.000000        0.000000  0.000000
# 2020.0        0.000000  0.000000  0.000000        0.000000  0.000000
# 2021.0        0.000000  0.000000  0.000000        0.000000  0.000000
#
# Country Name     Japan  Russian Federation  United States
# 2012.0        0.334051           11.283118       4.730549
# 2013.0        0.288355           11.108920       4.525593
# ...

# %%
df4.drop(df4.iloc[:, 1:56], inplace = True, axis = 1)
df4.columns.name = None
df4 = df4.set_index('Country Name')
df4
# Out:
#                                 2012.0     2013.0     2014.0     2015.0  \
# Country Name
# Aruba                         3.899966   5.815926   1.927228        NaN
# Africa Eastern and Southern  15.100000        NaN  10.500000  10.300000
# Afghanistan                   6.251328        NaN        NaN   9.783922
# Africa Western and Central   13.300000        NaN   8.100000   8.100000
# Angola                        4.847075        NaN        NaN        NaN
# ...                                ...        ...        ...        ...
# Kosovo                        4.985597   2.247684   3.018992   2.331002
# Yemen, Rep.                   6.603148   6.772149        NaN        NaN
# South Africa                 30.600000  31.700000  32.600000  33.800000
# Zambia                        6.118154   5.808442   5.357215   5.371750
# Zimbabwe                      7.479900        NaN        NaN        NaN
#
#                                 2016.0     2017.0    2018.0  2019.0  2020.0  \
# ...

# %%
df4 = df4.fillna(0)
df4
# Out:
#                                 2012.0     2013.0     2014.0     2015.0  \
# Country Name
# Aruba                         3.899966   5.815926   1.927228   0.000000
# Africa Eastern and Southern  15.100000   0.000000  10.500000  10.300000
# Afghanistan                   6.251328   0.000000   0.000000   9.783922
# Africa Western and Central   13.300000   0.000000   8.100000   8.100000
# Angola                        4.847075   0.000000   0.000000   0.000000
# ...                                ...        ...        ...        ...
# Kosovo                        4.985597   2.247684   3.018992   2.331002
# Yemen, Rep.                   6.603148   6.772149   0.000000   0.000000
# South Africa                 30.600000  31.700000  32.600000  33.800000
# Zambia                        6.118154   5.808442   5.357215   5.371750
# Zimbabwe                      7.479900   0.000000   0.000000   0.000000
#
#                                 2016.0     2017.0    2018.0  2019.0  2020.0  \
# ...

# %%
df4t = df4.transpose()
df4t
# Out:
# Country Name     Aruba  Africa Eastern and Southern  Afghanistan  \
# 2012.0        3.899966                         15.1     6.251328
# 2013.0        5.815926                          0.0     0.000000
# 2014.0        1.927228                         10.5     0.000000
# 2015.0        0.000000                         10.3     9.783922
# 2016.0        0.000000                          0.0     6.551163
# 2017.0        0.000000                          0.0     6.678401
# 2018.0        0.000000                          0.0     6.655561
# 2019.0        0.000000                          0.0     0.000000
# 2020.0        0.000000                          0.0     0.000000
# 2021.0        0.000000                          0.0     0.000000
#
# Country Name  Africa Western and Central    Angola   Albania  Andorra  \
# 2012.0                              13.3  4.847075  5.387615      0.0
# 2013.0                               0.0  0.000000  4.270284      0.0
# ...

# %%
df1.columns.name = None
df1 = df1.set_index('Country Name')
df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-677-7ffc05bb4007> in <module>
#       1 df1.columns.name = None
# ----> 2 df1 = df1.set_index('Country Name')
#       3 df1
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4549
#    4550         if missing:
# -> 4551             raise KeyError(f"None of {missing} are in the columns")
#    4552
#    4553         if inplace:
#
# KeyError: "None of ['Country Name'] are in the columns"

# %% [markdown]
# ### NOW DATASETS ARE CLEANED & ARE PREPARED TO GET ANALYSED

# %% [markdown]
# #### TASK-1 Country with highest &lowest unemployment over the time?

# %%
print('Countries with Maximum Unemployment rate in each year: ')
df1.idxmax(axis=0, skipna=True)
# Out:
# Countries with Maximum Unemployment rate in each year:
# 2012.0           North Macedonia
# 2013.0           North Macedonia
# 2014.0           North Macedonia
# 2015.0    Bosnia and Herzegovina
# 2016.0              South Africa
# 2017.0              South Africa
# 2018.0              South Africa
# 2019.0              South Africa
# 2020.0              South Africa
# 2021.0              South Africa
# dtype: object

# %% [markdown]
# ##### above are the countries with highest unemployment rate in given years.

# %%
print('Countries with Minimum Unemployment rate in each year: ')
df1.idxmin(axis=0, skipna=True)
# Out:
# Countries with Minimum Unemployment rate in each year:
# 2012.0    Aruba
# 2013.0    Aruba
# 2014.0    Aruba
# 2015.0    Aruba
# 2016.0    Aruba
# 2017.0    Aruba
# 2018.0    Aruba
# 2019.0    Aruba
# 2020.0    Aruba
# 2021.0    Aruba
# dtype: object

# %% [markdown]
# ##### Aruba has zero values so we,ll ignore it for now.

# %%
df1 = df1.replace(0, np.NaN)

# %%
print('Countries with Minimum Unemployment rate in each year: ')
df1.idxmin(axis=0, skipna=True)
# Out:
# Countries with Minimum Unemployment rate in each year:
# 2012.0       Qatar
# 2013.0    Thailand
# 2014.0       Qatar
# 2015.0       Qatar
# 2016.0       Qatar
# 2017.0    Cambodia
# 2018.0       Qatar
# 2019.0       Qatar
# 2020.0       Qatar
# 2021.0       Qatar
# dtype: object

# %% [markdown]
# ##### above are the countries with lowest unemployment rate in given years.

# %% [markdown]
# ### TASK 2 - UNEMPLOYMENTS RATES AND CRIME RATE IN SOME MAJOR COUNTRIES

# %% [markdown]
# ### Comparison between Unemployment rates of "India", "China", "Japan","Russian Federation","United States","Germany","United Kingdom" & "France" during years 2012-2021

# %%
axes = unem.plot(kind='bar', rot=0, subplots=True, title=['Unemployment Rate-2012', 'Unemployment Rate-2013','Unemployment Rate-2014','Unemployment Rate-2015','Unemployment Rate-2016','Unemployment Rate-2017','Unemployment Rate-2018','Unemployment Rate-2019','Unemployment Rate-2020','Unemployment Rate-2021',],figsize=(18, 20))

# %% [markdown]
# ##### Graph shows that FRANCE had highest unemployment rate every year only other than the year "2020" in which "India" & "United States" were almost equal to the France.
#
# ##### On the other hand, Japan maintained its Unemployment rates to the minimun during 2012-2021

# %% [markdown]
# ### Line Graph showing & Comparing the growths and dips of all the 8 Countries

# %%
#india = dff.iloc[4]
unemt.plot(kind='line', title='Unemployment over years', figsize=(18, 10))
# Out:
# <AxesSubplot:title={'center':'Unemployment over years'}>

# %% [markdown]
# ##### It can be seen from the graph that Countries other than France and Russia, minimized there unemployed citizens till 2019 until the Covid-19 hit, whereas India had almost constant unemployment rates unitl Covid-19 Lockdown. Also, surprisingly France survived the major epidemic and decreased thier unemployed people in later years.

# %% [markdown]
# ### Change In crime rate of the countries

# %%
ax = crmt.plot(kind='barh' , title='Crime Rate during years 2012-2021',figsize=(18, 20))
ax.set_xlabel("Crime Rate")
ax.set_ylabel("Year")
# Out:
# Text(0, 0.5, 'Year')

# %% [markdown]
# ##### From the bar graph it is seen that Russia had the highest crime rate, while Japan had the lowest in every year. Crime rate in United Kingdom has increased over the years.

# %%
crm2 = df3

# %%
crm2.columns.name = None
crm2 = df3.set_index('Country Name')
crm2t = crm2.transpose()

# %%
ax = crmt.plot(lw=2, colormap='jet', marker='.', markersize=10, 
         title='Change in Crime Rate over years')
ax.set_xlabel("Year")
ax.set_ylabel("Crime Rate")
# Out:
# Text(0, 0.5, 'Crime Rate')

# %% [markdown]
# ### TASK 3 - Compare Unemployment and Crime Rates of given countries.

# %%
# first we will get max and min employment rates
maxem = unem.idxmax(axis=0, skipna=True)
minem = unem.idxmin(axis=0, skipna=True)

# %%
# now on merging the dataframes
temp = pd.concat([maxem, minem], axis=1)

# %%
temp
# Out:
#                     0      1
# 2012.0         France  Japan
# 2013.0         France  Japan
# 2014.0         France  Japan
# 2015.0         France  Japan
# 2016.0         France  Japan
# 2017.0         France  Japan
# 2018.0         France  Japan
# 2019.0         France  Japan
# 2020.0  United States  Japan
# 2021.0         France  Japan

# %%
# now we will get maximum and minimun crime rate data
maxcr = crm.idxmax(axis=0, skipna=True)
mincr = crm.idxmin(axis=0, skipna=True)

# %%
temp1 = pd.concat([maxcr, mincr], axis=1)
temp1
# Out:
#                          0      1
# 2012.0  Russian Federation  Japan
# 2013.0  Russian Federation  Japan
# 2014.0  Russian Federation  Japan
# 2015.0  Russian Federation  Japan
# 2016.0  Russian Federation  Japan
# 2017.0  Russian Federation  Japan
# 2018.0  Russian Federation  Japan
# 2019.0               China  China
# 2020.0               China  China
# 2021.0               China  China

# %%
# on merging all datas
temp2 = pd.concat([temp,temp1],axis = 1)
temp2
# Out:
#                     0      1                   0      1
# 2012.0         France  Japan  Russian Federation  Japan
# 2013.0         France  Japan  Russian Federation  Japan
# 2014.0         France  Japan  Russian Federation  Japan
# 2015.0         France  Japan  Russian Federation  Japan
# 2016.0         France  Japan  Russian Federation  Japan
# 2017.0         France  Japan  Russian Federation  Japan
# 2018.0         France  Japan  Russian Federation  Japan
# 2019.0         France  Japan               China  China
# 2020.0  United States  Japan               China  China
# 2021.0         France  Japan               China  China
